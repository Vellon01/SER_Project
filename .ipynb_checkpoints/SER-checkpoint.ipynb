# %%
# %pip install librosa
import numpy as np
import librosa
# Out:
# Collecting librosa
#   Using cached librosa-0.11.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting audioread>=2.1.9 (from librosa)
#   Using cached audioread-3.1.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: numba>=0.51.0 in c:\users\vello\anaconda3\lib\site-packages (from librosa) (0.62.1)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\vello\anaconda3\lib\site-packages (from librosa) (2.3.5)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\vello\anaconda3\lib\site-packages (from librosa) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in c:\users\vello\anaconda3\lib\site-packages (from librosa) (1.7.2)
# Requirement already satisfied: joblib>=1.0 in c:\users\vello\anaconda3\lib\site-packages (from librosa) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\vello\anaconda3\lib\site-packages (from librosa) (5.2.1)
# Collecting soundfile>=0.12.1 (from librosa)
#   Using cached soundfile-0.13.1-py2.py3-none-win_amd64.whl.metadata (16 kB)
# Collecting pooch>=1.1 (from librosa)
#   Using cached pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa)
#   Using cached soxr-1.0.0-cp312-abi3-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\vello\anaconda3\lib\site-packages (from librosa) (4.15.0)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\vello\anaconda3\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\vello\anaconda3\lib\site-packages (from librosa) (1.1.1)
# Collecting standard-aifc (from librosa)
#   Using cached standard_aifc-3.13.0-py3-none-any.whl.metadata (969 bytes)
# Collecting standard-sunau (from librosa)
#   Using cached standard_sunau-3.13.0-py3-none-any.whl.metadata (914 bytes)
# Requirement already satisfied: packaging in c:\users\vello\anaconda3\lib\site-packages (from lazy_loader>=0.1->librosa) (25.0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\users\vello\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (0.45.1)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\vello\anaconda3\lib\site-packages (from pooch>=1.1->librosa) (4.5.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\vello\anaconda3\lib\site-packages (from pooch>=1.1->librosa) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\vello\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vello\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vello\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vello\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2026.1.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\vello\anaconda3\lib\site-packages (from scikit-learn>=1.1.0->librosa) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\vello\anaconda3\lib\site-packages (from soundfile>=0.12.1->librosa) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\vello\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.23)
# Collecting standard-chunk (from standard-aifc->librosa)
#   Using cached standard_chunk-3.13.0-py3-none-any.whl.metadata (860 bytes)
# Collecting audioop-lts (from standard-aifc->librosa)
#   Using cached audioop_lts-0.2.2-cp313-abi3-win_amd64.whl.metadata (2.0 kB)
# Using cached librosa-0.11.0-py3-none-any.whl (260 kB)
# Using cached audioread-3.1.0-py3-none-any.whl (23 kB)
# Using cached pooch-1.8.2-py3-none-any.whl (64 kB)
# Using cached soundfile-0.13.1-py2.py3-none-win_amd64.whl (1.0 MB)
# Using cached soxr-1.0.0-cp312-abi3-win_amd64.whl (172 kB)
# Using cached standard_aifc-3.13.0-py3-none-any.whl (10 kB)
# Using cached audioop_lts-0.2.2-cp313-abi3-win_amd64.whl (30 kB)
# Using cached standard_chunk-3.13.0-py3-none-any.whl (4.9 kB)
# Using cached standard_sunau-3.13.0-py3-none-any.whl (7.4 kB)
# Installing collected packages: standard-chunk, soxr, audioop-lts, standard-sunau, standard-aifc, soundfile, pooch, audioread, librosa
#
#    -------------------------- ------------- 6/9 [pooch]
#    ----------------------------------- ---- 8/9 [librosa]
#    ---------------------------------------- 9/9 [librosa]
#
# Successfully installed audioop-lts-0.2.2 audioread-3.1.0 librosa-0.11.0 pooch-1.8.2 soundfile-0.13.1 soxr-1.0.0 standard-aifc-3.13.0 standard-chunk-3.13.0 standard-sunau-3.13.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Feature extraction

# %%
def extract_features(data, sr):
    # Zero Crossing Rate
    zcr = np.mean(librosa.feature.zero_crossing_rate(y=data).T, axis=0)
    
    # Chroma (STFT)
    stft = np.abs(librosa.stft(data))
    chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sr).T, axis=0)
    
    # Mel Frequency Cepstral Coefficients
    mfccs = np.mean(librosa.feature.mfcc(y=data, sr=sr, n_mfcc=40).T, axis=0)
    
    # Stack them into one long array
    # Shape: (1 + 12 + 40) = 53 features
    result = np.hstack((zcr, chroma, mfccs))
    return result

# %% [markdown]
# # Preparing the data for CNN
